# %% [markdown]
# ## Introduction
#
# XGBoost is one of the leading ML model, so it seemed only fair to perform experiment on it.
#
# ## Description
#
# For this experiment, only Ratio dataset was used. Commonly used parameters along with weights were used for XGBoost. The recall produced was 0.8 for the negative class and 0.69 for the positive class with an AUC of 0.82934. Moreover, 'ppegt/at' was the most important feature.
#
# ## Conclusions
#
# Results seems to be better than RUSBoost and maybe hypertuning might give us better results. The AUC score produced is the highest so far. Mostly, ratios with 'at' seemed to be important. Only ppegt (Property, Plant and Equipment - Total (Gross)), csho (Common Shares Outstanding) and re(Retained Earnings) were the ones which appeared as most important features in top 10 with both 'sale' and 'at'.

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
# confusion matrix plot
def plot_cm(cm):
    import seaborn as sns
    import matplotlib.pyplot as plt
    sns.heatmap(cm, annot=True,cmap="OrRd",fmt='g')
    plt.title('confusion matrix')
    plt.xlabel('predicted')
    plt.ylabel('actual')
    plt.show()

# %%
# plots ROC curve
def ROC(y_test,probs):
    import sklearn.metrics as metrics
    fpr, tpr, threshold = metrics.roc_curve(y_test, probs)
    roc_auc = metrics.auc(fpr, tpr)

    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', label = f'AUC = {round(roc_auc,3)}')
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %%
df = pd.read_csv("Dataset/uni_ratios_fraud.csv",sep = ';')
df.head()
# Out:
#         g_id   fyear    gvkey  fraud  sale_flag  at_flag   sale/at   at/sale  \
# 0  100001990  1990.0  10000.0    0.0          0        0  1.203083  0.831198
# 1  100001991  1991.0  10000.0    0.0          0        0  1.361683  0.734385
# 2  100001992  1992.0  10000.0    0.0          0        0  1.428408  0.700080
# 3  100001993  1993.0  10000.0    0.0          0        0  1.376801  0.726321
# 4  100001994  1994.0  10000.0    0.0          0        0  1.365206  0.732490
#
#    act/sale    act/at  ...  sstk/sale   sstk/at  txp/sale    txp/at  txt/sale  \
# 0  0.631982  0.760326  ...   0.000024  0.000028  0.001105  0.001329  0.003804
# 1  0.545042  0.742175  ...   0.000037  0.000051  0.000922  0.001255  0.002201
# 2  0.495408  0.707644  ...   0.000037  0.000053  0.003290  0.004700  0.003626
# 3  0.521222  0.717620  ...   0.008726  0.012014  0.007921  0.010906  0.014081
# 4  0.524201  0.715642  ...   0.000840  0.001146  0.000000  0.000000  0.018308
#
#      txt/at  xint/sale   xint/at  prcc_f/sale  prcc_f/at
# 0  0.004577   0.037299  0.044873     0.015015   0.018064
# 1  0.002997   0.032109  0.043722     0.018465   0.025143
# 2  0.005180   0.023040  0.032910     0.024974   0.035673
# 3  0.019386   0.021179  0.029159     0.045252   0.062303
# 4  0.024994   0.019176  0.026179     0.030625   0.041810
#
# [5 rows x 60 columns]

# %%
df.describe()
# Out:
#                g_id          fyear          gvkey          fraud  \
# count  1.460450e+05  146045.000000  146045.000000  146045.000000
# mean   5.424364e+08    2002.011702   54243.435516       0.006601
# std    5.993746e+08       6.959894   59937.455765       0.080976
# min    1.004199e+07    1990.000000    1004.000000       0.000000
# 25%    1.065820e+08    1996.000000   10658.000000       0.000000
# 50%    2.508820e+08    2002.000000   25088.000000       0.000000
# 75%    6.658620e+08    2008.000000   66586.000000       0.000000
# max    3.172642e+09    2014.000000  317264.000000       1.000000
#
#            sale_flag        at_flag        sale/at        at/sale  \
# count  146045.000000  146045.000000  146045.000000  146045.000000
# mean        0.071225       0.004047       2.834339      16.423917
# std         0.257201       0.063485      47.186967     330.139351
# min         0.000000       0.000000     -11.538462   -1990.120000
# 25%         0.000000       0.000000       0.423298       0.680021
# 50%         0.000000       0.000000       0.888315       1.124941
# 75%         0.000000       0.000000       1.469601       2.359249
# max         1.000000       1.000000   13203.000000   60268.000000
#
#             act/sale         act/at  ...      sstk/sale        sstk/at  \
# count  146045.000000  146045.000000  ...  146045.000000  146045.000000
# mean        7.483634       0.495074  ...       5.437247       0.241497
# std       222.627523       0.273108  ...     168.909065       5.241214
# min      -333.263158      -0.666667  ...    -562.631579      -0.172085
# 25%         0.285714       0.266761  ...       0.000000       0.000000
# 50%         0.451608       0.494892  ...       0.004559       0.004269
# 75%         0.827804       0.717052  ...       0.078916       0.052289
# max     55955.000000       1.096045  ...   38934.000000     792.000000
#
#             txp/sale         txp/at       txt/sale         txt/at  \
# count  146045.000000  146045.000000  146045.000000  146045.000000
# mean        0.073672       0.006898      -0.019277       0.014842
# std         9.490696       0.164446      10.789259       0.522142
# min       -16.777778      -0.021008   -2857.375000     -36.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.005268       0.004720
# 75%         0.006241       0.005822       0.029825       0.027651
# max      2647.000000      61.000000    1946.500000     178.000000
#
#            xint/sale        xint/at    prcc_f/sale      prcc_f/at
# count  146045.000000  146045.000000  146045.000000  146045.000000
# mean        0.705279       0.264401       4.078857       1.798088
# std        27.866052      18.557445     314.809760     223.631466
# min       -47.603448      -0.286667     -21.000000       0.000000
# 25%         0.003179       0.002902       0.016759       0.013999
# 50%         0.014811       0.013998       0.061442       0.049785
# 75%         0.044776       0.031132       0.233926       0.161262
# max      6387.000000    6584.500000  111875.000000   80000.000000
#
# [8 rows x 60 columns]

# %%
# Splitting data in 80/20 ratio with a random seed of 42 to get consistent results.
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:,4:], df[['fraud']],test_size=0.20,random_state = 42)

# %%
from sklearn import preprocessing
scaler = preprocessing.StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
class_weights = sum(y_train['fraud']==0)/sum(y_train['fraud']==1)
class_weights
# Out:
# 147.0811153358682

# %%
# if more than one evaluation metric are given the last one is used for early stopping
# xgb_model = xgb.XGBClassifier(learning_rate = 0.8,eval_metric = 'auc',scale_pos_weight=class_weights)
xgb_model = xgb.XGBClassifier(max_depth = 4, eta = 0.09, nthread = 2, nrounds = 200, scale_pos_weight = class_weights, colsample_bytree = 0.7,
                 gamma = 2.5,
                 eval_metric = "auc",
                 objective = "binary:logistic")
xgb_model.fit(X_train, y_train, early_stopping_rounds=10, eval_set=[(X_test, y_test)])
# Out:
# C:\Users\umaid\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [14:30:28] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { nrounds } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.70437
# Will train until validation_0-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.74721
# [2]	validation_0-auc:0.75797
# [3]	validation_0-auc:0.76540
# [4]	validation_0-auc:0.76925
# [5]	validation_0-auc:0.77643
# [6]	validation_0-auc:0.77845
# [7]	validation_0-auc:0.78250
# [8]	validation_0-auc:0.78512
# [9]	validation_0-auc:0.78514
# [10]	validation_0-auc:0.78593
# [11]	validation_0-auc:0.78891
# [12]	validation_0-auc:0.78885
# [13]	validation_0-auc:0.79209
# [14]	validation_0-auc:0.79564
# [15]	validation_0-auc:0.79725
# [16]	validation_0-auc:0.80080
# [17]	validation_0-auc:0.79906
# [18]	validation_0-auc:0.80074
# [19]	validation_0-auc:0.80120
# [20]	validation_0-auc:0.80173
# [21]	validation_0-auc:0.80315
# [22]	validation_0-auc:0.80412
# [23]	validation_0-auc:0.80424
# [24]	validation_0-auc:0.80512
# [25]	validation_0-auc:0.80530
# [26]	validation_0-auc:0.80563
# [27]	validation_0-auc:0.80554
# [28]	validation_0-auc:0.80619
# [29]	validation_0-auc:0.80607
# [30]	validation_0-auc:0.80687
# [31]	validation_0-auc:0.80608
# [32]	validation_0-auc:0.80744
# [33]	validation_0-auc:0.80866
# [34]	validation_0-auc:0.80886
# [35]	validation_0-auc:0.80928
# [36]	validation_0-auc:0.80992
# [37]	validation_0-auc:0.81039
# [38]	validation_0-auc:0.81115
# [39]	validation_0-auc:0.81134
# [40]	validation_0-auc:0.81250
# [41]	validation_0-auc:0.81329
# [42]	validation_0-auc:0.81424
# [43]	validation_0-auc:0.81450
# [44]	validation_0-auc:0.81392
# [45]	validation_0-auc:0.81460
# [46]	validation_0-auc:0.81544
# [47]	validation_0-auc:0.81598
# [48]	validation_0-auc:0.81705
# [49]	validation_0-auc:0.81683
# [50]	validation_0-auc:0.81752
# [51]	validation_0-auc:0.81821
# [52]	validation_0-auc:0.81874
# [53]	validation_0-auc:0.81959
# [54]	validation_0-auc:0.81935
# [55]	validation_0-auc:0.81982
# [56]	validation_0-auc:0.81986
# [57]	validation_0-auc:0.81977
# [58]	validation_0-auc:0.82029
# [59]	validation_0-auc:0.81990
# [60]	validation_0-auc:0.81976
# [61]	validation_0-auc:0.82002
# [62]	validation_0-auc:0.82009
# [63]	validation_0-auc:0.82080
# [64]	validation_0-auc:0.82114
# [65]	validation_0-auc:0.82172
# [66]	validation_0-auc:0.82231
# [67]	validation_0-auc:0.82238
# [68]	validation_0-auc:0.82184
# [69]	validation_0-auc:0.82332
# [70]	validation_0-auc:0.82295
# [71]	validation_0-auc:0.82338
# [72]	validation_0-auc:0.82364
# [73]	validation_0-auc:0.82308
# [74]	validation_0-auc:0.82362
# [75]	validation_0-auc:0.82498
# [76]	validation_0-auc:0.82481
# [77]	validation_0-auc:0.82515
# [78]	validation_0-auc:0.82592
# [79]	validation_0-auc:0.82629
# [80]	validation_0-auc:0.82705
# [81]	validation_0-auc:0.82657
# [82]	validation_0-auc:0.82724
# [83]	validation_0-auc:0.82679
# [84]	validation_0-auc:0.82690
# [85]	validation_0-auc:0.82725
# [86]	validation_0-auc:0.82740
# [87]	validation_0-auc:0.82776
# [88]	validation_0-auc:0.82842
# [89]	validation_0-auc:0.82763
# [90]	validation_0-auc:0.82788
# [91]	validation_0-auc:0.82888
# [92]	validation_0-auc:0.82938
# [93]	validation_0-auc:0.82935
# [94]	validation_0-auc:0.83021
# [95]	validation_0-auc:0.83035
# [96]	validation_0-auc:0.83057
# [97]	validation_0-auc:0.83014
# [98]	validation_0-auc:0.82948
# [99]	validation_0-auc:0.82934
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.7, eta=0.09,
#               eval_metric='auc', gamma=2.5, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.0900000036,
#               max_delta_step=0, max_depth=4, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=2,
#               nrounds=200, nthread=2, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=147.0811153358682,
#               subsample=1, tree_method='exact', validate_parameters=1,
#               verbosity=None)

# %%
train_pred = xgb_model.predict(X_train)
print(classification_report(y_train,train_pred))
cm = confusion_matrix(y_train,train_pred)
plot_cm(cm)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.80      0.89    116047
#          1.0       0.03      0.95      0.06       789
#
#     accuracy                           0.80    116836
#    macro avg       0.52      0.87      0.48    116836
# weighted avg       0.99      0.80      0.88    116836

# %%
test_pred = xgb_model.predict(X_test)
print(classification_report(y_test,test_pred))
cm = confusion_matrix(y_test,test_pred)
plot_cm(cm)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.80      0.89     29034
#          1.0       0.02      0.69      0.04       175
#
#     accuracy                           0.79     29209
#    macro avg       0.51      0.74      0.46     29209
# weighted avg       0.99      0.79      0.88     29209

# %%
from matplotlib import pyplot
from xgboost import plot_importance
fig, ax = plt.subplots(figsize=(20, 10))
# plot
plot_importance(xgb_model,ax = ax,max_num_features = 10)
pyplot.show()

# %%
# !pip install graphviz
# Out:
# Collecting graphviz
#   Downloading graphviz-0.14.2-py2.py3-none-any.whl (18 kB)
# Installing collected packages: graphviz
# Successfully installed graphviz-0.14.2

# %%
df.head()
# Out:
#         g_id   fyear    gvkey  fraud  sale_flag  at_flag   sale/at   at/sale  \
# 0  100001990  1990.0  10000.0    0.0          0        0  1.203083  0.831198
# 1  100001991  1991.0  10000.0    0.0          0        0  1.361683  0.734385
# 2  100001992  1992.0  10000.0    0.0          0        0  1.428408  0.700080
# 3  100001993  1993.0  10000.0    0.0          0        0  1.376801  0.726321
# 4  100001994  1994.0  10000.0    0.0          0        0  1.365206  0.732490
#
#    act/sale    act/at  ...  sstk/sale   sstk/at  txp/sale    txp/at  txt/sale  \
# 0  0.631982  0.760326  ...   0.000024  0.000028  0.001105  0.001329  0.003804
# 1  0.545042  0.742175  ...   0.000037  0.000051  0.000922  0.001255  0.002201
# 2  0.495408  0.707644  ...   0.000037  0.000053  0.003290  0.004700  0.003626
# 3  0.521222  0.717620  ...   0.008726  0.012014  0.007921  0.010906  0.014081
# 4  0.524201  0.715642  ...   0.000840  0.001146  0.000000  0.000000  0.018308
#
#      txt/at  xint/sale   xint/at  prcc_f/sale  prcc_f/at
# 0  0.004577   0.037299  0.044873     0.015015   0.018064
# 1  0.002997   0.032109  0.043722     0.018465   0.025143
# 2  0.005180   0.023040  0.032910     0.024974   0.035673
# 3  0.019386   0.021179  0.029159     0.045252   0.062303
# 4  0.024994   0.019176  0.026179     0.030625   0.041810
#
# [5 rows x 60 columns]
